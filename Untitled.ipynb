# %%
import os
import pandas as pd
import numpy as np
from stock_reader import reader
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
import logging
import os
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import Flatten
from keras.layers import GRU
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.optimizers import Adam
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints
from keras.engine.input_layer import Input
from keras import backend as K
from keras.models import Model

# %%
from tensorflow import set_random_seed
set_random_seed(7)
np.random.seed(7)

# %%
look_back = 1

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
# https://www.kaggle.com/qqgeogor/keras-lstm-attention-glove840b-lb-0-043
class Attention(Layer):
    
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
if __name__ == '__main__':
    stock_code = '005930'  # 삼성전자

    # 주식 데이터 준비
    pandf = reader()

    # 기간 필터링
#    pandf = chart_data[(chart_data['date'] >= '2010-11-01') &
#                                  (chart_data['date'] <= '2017-12-31')]
#    pandf = pandf.dropna()
    # convert nparray
    nparr = pandf['close'].values[::-1].reshape(-1,1)
    nparr.astype('float32')
# Out:
# Enter Code or Symbol :  035420
# Enter start date(YYYY-MM--DD) :  20070101
# Enter end date(YYYY-MM--DD) :  20200101
#      Symbol   Name                            Sector
# 155  035420  NAVER  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업
#
#               open    high     low   close  volume    change
# Date
# 2007-01-02  115700  115899  114000  114500  212410  0.003506
# 2007-01-03  114900  114900  111800  112200  211285 -0.020087
# 2007-01-04  113700  117000  113000  117000  681798  0.042781
# 2007-01-05  119200  125200  117500  124300  650768  0.062393
# 2007-01-08  122000  123000  118400  121500  283582 -0.022526
# ...            ...     ...     ...     ...     ...       ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242
# 2019-12-27  182000  185000  179000  183500  323473  0.016620
# 2019-12-30  183500  190000  183500  186500  376541  0.016349
#
# [3189 rows x 6 columns]
# There are 3189 number of days in the dataset.

# %%
    nparr = pandf['close'].values[::].reshape(-1,1)
    nparr.astype('float32')
    nptf1=np.array(pandf)
    print(nptf1)
    print("nparr :",nparr.shape,"nptf1 :",nptf1.shape)
# Out:
# [[ 1.15700000e+05  1.15899000e+05  1.14000000e+05  1.14500000e+05
#    2.12410000e+05  3.50569676e-03]
#  [ 1.14900000e+05  1.14900000e+05  1.11800000e+05  1.12200000e+05
#    2.11285000e+05 -2.00873362e-02]
#  [ 1.13700000e+05  1.17000000e+05  1.13000000e+05  1.17000000e+05
#    6.81798000e+05  4.27807487e-02]
#  ...
#  [ 1.81500000e+05  1.83000000e+05  1.79000000e+05  1.80500000e+05
#    1.73426000e+05 -8.24175824e-03]
#  [ 1.82000000e+05  1.85000000e+05  1.79000000e+05  1.83500000e+05
#    3.23473000e+05  1.66204986e-02]
#  [ 1.83500000e+05  1.90000000e+05  1.83500000e+05  1.86500000e+05
#    3.76541000e+05  1.63487738e-02]]
# nparr : (3189, 1) nptf1 : (3189, 6)

# %%
    # normalization
    scaler = MinMaxScaler(feature_range=(0, 1))
#    nptf = scaler.fit_transform(nparr)
    nptf = scaler.fit_transform(nparr)
    print(nptf.shape)

    # split train, test
    train_size = int(len(nptf) * 0.9)
    test_size = len(nptf) - train_size
    train, test = nptf[0:train_size], nptf[train_size:len(nptf)]
    print(len(train), len(test))

    # create dataset for learning
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    print("trainX :",trainX.shape,"trainY :",trainY.shape,"testX :",testX.shape,"testY :",testY.shape ,"(행,열,피처)")
    

    # reshape input to be [samples, time steps, features]
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[2])) # trainX.shape[1] --> [2] 로 바꿈 )
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[2]))
  #  print(trainX)
  #  print(testX)
# Out:
# (3189, 1)
# 2870 319
# trainX : (2868, 1, 1) trainY : (2868, 1) testX : (317, 1, 1) testY : (317, 1) (행,열,피처)

# %%
    # simple lstm network learning
    model = Sequential()
    model.add(LSTM(128,  return_sequences=True, activation="relu", input_shape=(1, look_back))) # input_shape=(1, look_back) --> (X_train.shape[1], X_train.shape[2]) 
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Attention(look_back))
#    model.add(LSTM(128,  return_sequences=False, activation="relu", input_shape=(1, look_back)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(1, activation="sigmoid"))
    #model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='adam',metrics = ['mae'])
    model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 1, 128)            66560
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 1, 128)            512
# _________________________________________________________________
# attention_17 (Attention)     (None, 128)               129
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 67,842
# Trainable params: 67,330
# Non-trainable params: 512
# _________________________________________________________________

# %%
    from keras.callbacks import EarlyStopping
    early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1) # early_stop 
    model.fit(trainX, trainY, epochs=40, batch_size=32, verbose=2)#callbacks=[early_stop]

    # make prediction
    testPredict = model.predict(testX)
    testPredict = scaler.inverse_transform(testPredict)
    testY = scaler.inverse_transform(testY)
    testScore = math.sqrt(mean_squared_error(testY, testPredict))
    print('Train Score: %.2f RMSE' % testScore)

    # predict last value (or tomorrow?)
    lastX = nptf[-1]
    lastX = np.reshape(lastX, (1, 1, 1))
    lastY = model.predict(lastX)
    lastY = scaler.inverse_transform(lastY)
    print('Predict the Close value of final day: %d' % lastY)  # 데이터 입력 마지막 다음날 종가 예측
# Out:
# Epoch 1/40
#  - 3s - loss: 0.0296 - mean_absolute_error: 0.1299
# Epoch 2/40
#  - 1s - loss: 0.0123 - mean_absolute_error: 0.0803
# Epoch 3/40
#  - 1s - loss: 0.0063 - mean_absolute_error: 0.0586
# Epoch 4/40
#  - 1s - loss: 0.0046 - mean_absolute_error: 0.0518
# Epoch 5/40
#  - 1s - loss: 0.0034 - mean_absolute_error: 0.0449
# Epoch 6/40
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0418
# Epoch 7/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0409
# Epoch 8/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0417
# Epoch 9/40
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0433
# Epoch 10/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0415
# Epoch 11/40
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0404
# Epoch 12/40
#  - 1s - loss: 0.0032 - mean_absolute_error: 0.0441
# Epoch 13/40
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0410
# Epoch 14/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0412
# Epoch 15/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0409
# Epoch 16/40
#  - 1s - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 17/40
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0419
# Epoch 18/40
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0435
# Epoch 19/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0418
# Epoch 20/40
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0416
# Epoch 21/40
#  - 1s - loss: 0.0032 - mean_absolute_error: 0.0442
# Epoch 22/40
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0419
# Epoch 23/40
#  - 1s - loss: 0.0023 - mean_absolute_error: 0.0368
# Epoch 24/40
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0409
# Epoch 25/40
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0386
# Epoch 26/40
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 27/40
#  - 1s - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 28/40
#  - 1s - loss: 0.0025 - mean_absolute_error: 0.0391
# Epoch 29/40
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0416
# Epoch 30/40
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0416
# Epoch 31/40
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0423
# Epoch 32/40
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0395
# Epoch 33/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0410
# Epoch 34/40
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 35/40
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0404
# Epoch 36/40
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0409
# Epoch 37/40
#  - 1s - loss: 0.0025 - mean_absolute_error: 0.0387
# Epoch 38/40
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0402
# Epoch 39/40
#  - 1s - loss: 0.0025 - mean_absolute_error: 0.0389
# Epoch 40/40
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0396
# Train Score: 9269.59 RMSE
# Predict the Close value of final day: 196456

# %%
# plot
    plt.rcParams["figure.figsize"] = (20,10)
    plt.plot(testPredict, label = 'Predict')
    plt.plot(testY, label = 'Real data')
    plt.xlabel('Time in Days')
    plt.ylabel('Value of Samsung Stocks')
    plt.legend(loc = 'upper left')
    plt.show()

# %%
from sklearn.externals import joblib 
# 객체를 pickled binary file 형태로 저장한다 
file_name = 'scale.pkl' 
joblib.dump(scaler, file_name)
# Out:
# ['1scale.pkl']

# %%
from keras.models import load_model
model.save('LSTM.h5')

# %% [markdown]
# #TRAIDNG

# %%
count = int(np.ceil(len(pandf) * 0.1))
signals = pd.DataFrame(index=pandf.index)
signals['signal'] = 0.0
signals['trend'] = pandf['close']

signals=signals[-testPredict.shape[0]:]
signals['predict'] = testPredict
signals.loc[signals['predict'] < signals.trend, 'signal'] = -1 # 매도 selling
signals.loc[signals['predict'] >= signals.trend * 1.007, 'signal'] = 1 #매수 buying
signals.reset_index(drop=True, inplace=True)
signals
# Out:
#      signal   trend        predict
# 0       1.0  145206  154738.343750
# 1       1.0  145406  155125.515625
# 2       1.0  146207  153771.656250
# 3       1.0  144805  153964.812500
# 4       1.0  146207  154738.343750
# ..      ...     ...            ...
# 312     1.0  184000  188694.421875
# 313     1.0  182000  193386.406250
# 314     1.0  180500  193901.421875
# 315     1.0  183500  191833.640625
# 316     1.0  186500  190269.515625
#
# [317 rows x 3 columns]

# %%
plt.figure(figsize = (15,5))
plt.plot(signals['predict'],label='predict')
plt.plot(signals['trend'],label='real data')
plt.legend(loc = 'upper left')

# %%
def buy_stock( ## 클래스로 바꿔야할듯 
    real_movement,
    signal,
    predict,
    initial_money = 10000000,
    max_buy = 100,
    max_sell = 100,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    global 평단가,거래금
    states_real_buy=[]
    states_real_sell=[]
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0
    평단가 = 0
    거래금 = 0

    def buy(i, initial_money, current_inventory):
        global 평단가, 거래금
        
        shares = initial_money // real_movement[i]
        if shares < 1: # 가지고 있는 돈이 주가보다 낮을 경우 
            print(
                'day %d: 현재 잔고 : %d, 매수금이 부족합니다. 현재 주가 : %d'
                % (i, initial_money, real_movement[i])
            )
        else: # 가지고 있는 돈이 살수 있는 주가보다 높을 경우 
            states_real_buy.append(i) 
           # if shares > max_buy: 
            if predict[i] > real_movement[i] * 1.015 : 
                buy_units = min(shares , max_buy*3) # 수익률이 1.5% 이상이면 300주 매수 
            elif predict[i] > real_movement[i] * 1.01 : 
                buy_units = min(shares , max_buy*2) # 수익률이 1% 이상이면 200주 매수
            elif predict[i] > real_movement[i] * 1.007 : 
                buy_units = min(shares , max_buy*1) # 수익률이 0.7% 이상이면 100주 매수 
            else:
                buy_units = 0
                states_real_buy.pop(-1)
                #buy_units = shares # 살수 있는 만큼 산다. 
            initial_money -= buy_units * real_movement[i]
            거래금 += buy_units * real_movement[i]
            
            current_inventory += buy_units
            평단가 = 거래금 // current_inventory
            
            print(
                'day %d: 주문수량 : %d 주문수량 * 매수가 : %d, 현재 잔고 : %d, 주식 보유량 : %d, 평단가 :%0.2f '
                % (i, buy_units, buy_units * real_movement[i], initial_money, current_inventory,평단가)
            )
            states_buy.append(0) # 주식을 샀을 경우 0을 붙혀줌
            ####
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(signals))):
        state = signal[i]
        if state == 1: ##########signal 1 매수 
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
            #### 시그널 1일때 날짜를 붙혀줌
        elif state == -1: ########### signal -1 매도
            if current_inventory == 0:
                    print('day %d: 보유량이 없어서 매도를 하지 않았습니다' % (i))
            else:
                states_real_sell.append(i)
               # if current_inventory > max_sell: 
                ### 평단가에 따른 분할 매도 진행  (수익률이 0.7 )
                if real_movement[i] > 평단가 *1.015 : 
                    sell_units = min(current_inventory,max_sell*3) # 수익률이 1.5% 이상이면 300주 매도                                                          
                elif real_movement[i] > 평단가*1.01 :
                    sell_units = min(current_inventory,max_sell*2) # 수익률이 1% 이상이면 200주 매도 
                elif real_movement[i] > 평단가*1.007 :
                    sell_units = min(current_inventory,max_sell*1) # 수익률이 0.7% 이상이면 100주 매도
                else: 
                    sell_units = 0
                    states_real_sell.pop(-1)
                    
              #  else:
               #     sell_units = current_inventory                  
                current_inventory -= sell_units # 판다
                거래금 -= sell_units * real_movement[i]
                평단가 = 거래금 // current_inventory
                
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = ( 
                        np.log(real_movement[i] / real_movement[states_buy[-1]])
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, 매도량 : %d 매도가 : %d, 수익률: %0.2f %%, 현재 잔고 : %d, 주식 보유량 : %d, 평단가 : %0.2f'
                    % (i, sell_units, total_sell, invest, initial_money, current_inventory, 평단가)
                )
            states_sell.append(i)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest, current_inventory,states_real_buy,states_real_sell

# %%
states_buy, states_sell, total_gains, invest,current_inventory,states_real_buy,states_real_sell = buy_stock(signals['trend'], signals['signal'], signals['predict'])
# Out:
# day 0: 주문수량 : 68 주문수량 * 매수가 : 9874008, 현재 잔고 : 125992, 주식 보유량 : 68, 평단가 :145206.00
# day 1: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 145406
# day 2: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 146207
# day 3: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 144805
# day 4: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 146207
# day 5: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 145807
# day 6: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 145206
# day 7: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 146408
# day 8: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 146408
# day 9: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 145206
# day 10: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 142803
# day 11: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 143403
# day 12: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 142803
# day 13: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 137996
# day 14: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 139197
# day 15: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 141000
# day 16: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 142000
# day 17: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 136000
# day 18: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 133500
# day 19: 현재 잔고 : 125992, 매수금이 부족합니다. 현재 주가 : 130000
# day 20: 주문수량 : 1 주문수량 * 매수가 : 125000, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 :144913.00
# day 21: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127500
# day 22: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129000
# day 23: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 125500
# day 24: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 25: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 26: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 27: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 109500
# day 28: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 110500
# day 29: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114500
# day 30: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111500
# day 31: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 116500
# day 32: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113500
# day 33: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 117000
# day 34: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115500
# day 35: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 116500
# day 36: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115000
# day 37: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115000
# day 38: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 116000
# day 39: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115500
# day 40: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 112500
# day 41: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 112500
# day 42: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111500
# day 43: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 108000
# day 44: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 106500
# day 45: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 109500
# day 46, 매도량 : 0 매도가 : 0, 수익률: 4.03 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 47, 매도량 : 0 매도가 : 0, 수익률: 12.44 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 48, 매도량 : 0 매도가 : 0, 수익률: 13.24 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 49: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129000
# day 50: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130500
# day 51: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126500
# day 52: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126000
# day 53: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123500
# day 54: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 125000
# day 55: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120000
# day 56: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121000
# day 57: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 58: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123000
# day 59: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124500
# day 60: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124000
# day 61: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123500
# day 62: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 63: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 64: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127500
# day 65: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 66: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121500
# day 67: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123000
# day 68: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 69: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 70: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 71: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 72: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 73: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 125500
# day 74, 매도량 : 0 매도가 : 0, 수익률: 4.67 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 75: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130000
# day 76: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 133000
# day 77: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 131000
# day 78: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 131000
# day 79: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 80: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 132500
# day 81: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 132500
# day 82: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 136000
# day 83: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 137500
# day 84: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 131000
# day 85: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130000
# day 86: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 132500
# day 87: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129500
# day 88: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130000
# day 89: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 132000
# day 90: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 136000
# day 91: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 136000
# day 92: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 136000
# day 93: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 133500
# day 94: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129000
# day 95: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126000
# day 96: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 125500
# day 97: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123500
# day 98: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 125000
# day 99: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127500
# day 100: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127500
# day 101: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 102: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126500
# day 103: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 104: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129000
# day 105: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 106: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126000
# day 107: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 131500
# day 108: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 129500
# day 109: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 133000
# day 111: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 135500
# day 112: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 137500
# day 113: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138500
# day 114: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 133000
# day 115: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 133500
# day 116: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130500
# day 117: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130500
# day 118: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 131000
# day 119: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130500
# day 120: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 132000
# day 121: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 130500
# day 122: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 128500
# day 123: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 128000
# day 124: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 127000
# day 125: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126000
# day 126: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 126500
# day 127: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123000
# day 128: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 129: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124000
# day 130: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124000
# day 131: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124500
# day 132: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 133: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 134: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123000
# day 135: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121500
# day 136: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121500
# day 137: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 138: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121500
# day 139: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119500
# day 140: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119500
# day 141: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119500
# day 142: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119500
# day 143: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 144: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 145: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 146: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120500
# day 147: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121000
# day 148: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120500
# day 149: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 150: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120000
# day 151: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119500
# day 152: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 153: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124000
# day 154: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 124000
# day 155: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123500
# day 156: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 157: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 158: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 159: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122000
# day 160: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120000
# day 161: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 162: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121000
# day 163: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118500
# day 164: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114500
# day 165: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 166: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 167: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113500
# day 168: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 110500
# day 169: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 108500
# day 170: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 109500
# day 171: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 112000
# day 172: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111500
# day 173: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115000
# day 174: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111000
# day 175: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 110500
# day 176: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111000
# day 177: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114000
# day 178: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 179: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114000
# day 180: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 181: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111500
# day 182: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 110500
# day 183: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 109000
# day 184: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 110000
# day 185: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 111500
# day 186: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113000
# day 187: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 113500
# day 188: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114500
# day 189: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115500
# day 190: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115000
# day 191: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114000
# day 192: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 114500
# day 193: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115000
# day 194: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 117500
# day 195: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 196: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121000
# day 197: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118500
# day 198: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115500
# day 199: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 115500
# day 200: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 117000
# day 201: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 117000
# day 202: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 118000
# day 203: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120000
# day 204: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 119000
# day 205: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 120500
# day 206: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 207: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 121000
# day 208: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 122500
# day 209: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 123500
# day 210, 매도량 : 0 매도가 : 0, 수익률: 8.16 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 211, 매도량 : 0 매도가 : 0, 수익률: 13.25 %, 현재 잔고 : 992, 주식 보유량 : 69, 평단가 : 144913.00
# day 212: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138500
# day 213: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138500
# day 214: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138000
# day 215: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 140500
# day 216: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 142000
# day 217: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138000
# day 218: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 138500
# day 219: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 137500
# day 220: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 140000
# day 221: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 142500
# day 222: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 140500
# day 223: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 142500
# day 224: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 139000
# day 225: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 139500
# day 226: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 139000
# day 227: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 145500
# day 229: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 148000
# day 230: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 148500
# day 231: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 143500
# day 232: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 146500
# day 233: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 146500
# day 234: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 145000
# day 235: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 146500
# day 236: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 150000
# day 237: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 150500
# day 238: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 151000
# day 239: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 147000
# day 240: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 149500
# day 241: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153000
# day 242: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 150500
# day 243: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153500
# day 244: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 154500
# day 245: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 155000
# day 246: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 159000
# day 247: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157500
# day 248: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157000
# day 249: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157000
# day 250: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 158000
# day 251: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 158000
# day 252: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 158000
# day 253: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 156000
# day 254: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157000
# day 255: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 160000
# day 256: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157000
# day 257: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 150500
# day 258: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153000
# day 259: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153500
# day 260: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153500
# day 261: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 156000
# day 262: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 156000
# day 263: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 151500
# day 264: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 154500
# day 265: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153000
# day 266: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 150500
# day 267: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 152000
# day 268: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 154000
# day 269: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 152500
# day 270: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153000
# day 271: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 152500
# day 272: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 157000
# day 273: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 153000
# day 274: 현재 잔고 : 992, 매수금이 부족합니다. 현재 주가 : 154500
# day 275, 매도량 : 69 매도가 : 11316000, 수익률: 5.97 %, 현재 잔고 : 11316992, 주식 보유량 : 0, 평단가 : 0.00
# day 276: 보유량이 없어서 매도를 하지 않았습니다
# day 277: 주문수량 : 68 주문수량 * 매수가 : 11186000, 현재 잔고 : 130992, 주식 보유량 : 68, 평단가 :145132.00
# day 278: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 161500
# day 279: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 161500
# day 280: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 165500
# day 281: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 163500
# day 282: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 163000
# day 283: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 162000
# day 284: 현재 잔고 : 130992, 매수금이 부족합니다. 현재 주가 : 158000
# day 285, 매도량 : 68 매도가 : 12240000, 수익률: 13.04 %, 현재 잔고 : 12370992, 주식 보유량 : 0, 평단가 : 0.00
# day 286: 보유량이 없어서 매도를 하지 않았습니다
# day 287: 주문수량 : 69 주문수량 * 매수가 : 12316500, 현재 잔고 : 54492, 주식 보유량 : 69, 평단가 :144137.00
# day 288: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 170500
# day 289: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 169500
# day 290: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 170000
# day 291: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 167500
# day 292: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 174000
# day 293: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 173000
# day 294: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 172500
# day 295: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 173000
# day 296: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 172000
# day 297: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 171500
# day 298: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 172000
# day 299: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 174500
# day 300: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 170500
# day 301: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 174000
# day 302: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 175000
# day 303: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 174500
# day 304: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 174000
# day 305: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 175500
# day 306: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 175500
# day 307: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 179500
# day 308: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 180500
# day 309: 현재 잔고 : 54492, 매수금이 부족합니다. 현재 주가 : 178500

# %%
close = signals['trend']
fig = plt.figure(figsize = (20,5))
plt.plot(close, color='r', lw=2.)
plt.plot(signals['predict'])
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_real_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('CURRENT STATE : total gains %d won , total investment %0.2f%%, current inventory %f'%(total_gains, invest, current_inventory))
plt.legend()
plt.show()

profit = (close.iloc[-1]*current_inventory)+total_gains
print("currnet profit(in value) : ", profit)
# Out:
# currnet profit(in value) :  2922992

# %%
close = signals['trend']
fig = plt.figure(figsize = (20,5))
plt.plot(close, color='r', lw=2.)
plt.plot(signals['predict'])
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_real_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_real_sell)
plt.title('CURRENT STATE : total gains %d won , total investment %0.2f%%, current inventory %f'%(total_gains, invest, current_inventory))
plt.legend()
plt.show()

profit = (close.iloc[-1]*current_inventory)+total_gains
print("currnet profit(in value) : ", profit)
# Out:
# currnet profit(in value) :  2922992
